# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/client/session.py:1768: UserWarning: An interactive session is already active. This can cause out-of-memory errors in some cases. You must explicitly call `InteractiveSession.close()` to release resources held by the other session(s).
#   warnings.warn('An interactive session is already active. This can '

# %%
import pandas as pd
import numpy as np
import datetime
# !pip install pandas_summary
from pandas_summary import DataFrameSummary
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas_summary in /usr/local/lib/python3.7/dist-packages (0.2.0)
# Requirement already satisfied: datatile in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.0.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.21.6)
# Requirement already satisfied: traceml<1.1 in /usr/local/lib/python3.7/dist-packages (from datatile->pandas_summary) (1.0.3)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)

# %%
from tensorflow.keras.utils import to_categorical

# %%
df = pd.read_feather('/content/drive/MyDrive/Redes Neuronales/TP2/kaggle-rossman-master/train_normalized_data.fth')
df_test = pd.read_feather('/content/drive/MyDrive/Redes Neuronales/TP2/kaggle-rossman-master/test_normalized_data.fth')

# %%
cat_vars = ['Store', 'DayOfWeek', 'Year', 'Month', 'Day', 'StateHoliday', 'CompetitionMonthsOpen', 'Promo2Weeks', 
            'StoreType', 'Assortment', 'PromoInterval', 'CompetitionOpenSinceYear', 'Promo2SinceYear', 'State', 
            'Week', 'Events', 'Promo_fw', 'Promo_bw', 'StateHoliday_bool_fw', 'StateHoliday_bool_bw', 'SchoolHoliday_fw', 'SchoolHoliday_bw']

cat_vars = ['Store', 'DayOfWeek']

# %%
contin_vars = ['CompetitionDistance', 
   'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC', 'Precipitationmm',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday_bool', 'BeforeStateHoliday_bool', 'Promo', 'SchoolHoliday', 'StateHoliday_bool']
contin_vars = ['BeforeStateHoliday_bool', 'Max_TemperatureC']

# %%
uniques = DataFrameSummary(df[cat_vars]).summary().loc[['uniques']]

# %%
uniques.T
# Out:
#           uniques
# Store        1115
# DayOfWeek       7

# %% [markdown]
# # Asignación de dimensión de embeddings

# %%
cat_var_dict = {'Store': 50, 'DayOfWeek': 2, 'Year': 2, 'Month': 2,
'Day': 10, 'StateHoliday': 2, 'CompetitionMonthsOpen': 2,
'Promo2Weeks': 1, 'StoreType': 2, 'Assortment': 3, 'PromoInterval': 3,
'CompetitionOpenSinceYear': 4, 'Promo2SinceYear': 4, 'State': 6,
'Week': 25, 'Events': 4, 'Promo_fw': 1,
'Promo_bw': 1, 'StateHoliday_bool_fw': 1,
'StateHoliday_bool_bw': 1, 'SchoolHoliday_fw': 1,
'SchoolHoliday_bw': 1}

# %%
for v in cat_vars:
    uniques_ = df[v].unique()
    uniques_.sort()
    print(v, cat_var_dict[v], len(uniques_), uniques_)
    print()
# Out:
# Store 50 1115 [   0    1    2 ... 1112 1113 1114]
#
# DayOfWeek 2 7 [0 1 2 3 4 5 6]

# %% [markdown]
# # Definición de modelo

# %%
add_customers = True
log_output = False
output_activation = 'linear'

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Embedding, Input, Flatten, Concatenate, Dense, BatchNormalization, Activation, LeakyReLU, Dropout
from tensorflow.keras.regularizers import l2

# %%
def get_cat_vars_model(cat_vars, uniques, cat_var_dict):
    cat_vars_embed_outs = []
    cat_var_inputs = []
    for cat_var in cat_vars:
        cat_var_in = Input(shape=(1,), name=f"{cat_var}_input")
        cat_var_inputs.append(cat_var_in)
        embed_out = Embedding(uniques[cat_var][0], cat_var_dict[cat_var], name=f'{cat_var}_Embed')(cat_var_in)
        flatten_out = Flatten(name=f"{cat_var}_flat")(embed_out)
        cat_vars_embed_outs.append(flatten_out)
    return cat_var_inputs, cat_vars_embed_outs

def get_cont_vars_input(contin_vars, dense_layer=False):
    cont_vars_inputs = []
    cont_vars_outputs = []
    for cont_var in contin_vars:
        cont_var_in = Input(shape=(1,), name=f"{cont_var}_input")
        cont_vars_inputs.append(cont_var_in)
        if dense_layer:
            cont_var_out = Dense(1, name=f"{cont_var}_input", activation = 'linear')(cont_var_in)
            cont_vars_outputs.append(cont_var_out)
        else:
            cont_vars_outputs.append(cont_var_in)
    return cont_vars_inputs, cont_vars_outputs

# %%
cat_var_inputs, cat_vars_embed_outs = get_cat_vars_model(cat_vars, uniques, cat_var_dict)
cont_vars_inputs,  cont_vars_outs= get_cont_vars_input(contin_vars)

# %%
# Descomentar para ver resultados
# cat_vars_embed_outs
# cat_var_inputs
# cont_vars_inputs
# cont_vars_outs

# %%
first_hidden_units = 1000
second_hidden_units = 500
l2_lambda = 1e-3
merged = Concatenate(name='All_Concatenate')(cat_vars_embed_outs + cont_vars_inputs)
x = Dense(first_hidden_units, kernel_initializer="uniform", kernel_regularizer=l2(l2_lambda))(merged)
# x = BatchNormalization()(x)
x = Activation('relu')(x)
# x = LeakyReLU()(x)
x = Dense(second_hidden_units, kernel_initializer="uniform", kernel_regularizer=l2(l2_lambda))(x)
# x = BatchNormalization()(x)
x = Activation('relu')(x)
# x = LeakyReLU()(x)

output_1 = Dense(1, name='Sales', activation=output_activation)(x)
output_2 = Dense(1, name='Customers', activation=output_activation)(x)

# %%
if add_customers:
    model = Model(cat_var_inputs + cont_vars_inputs, [output_1, output_2])
else: 
    model = Model(cat_var_inputs + cont_vars_inputs, [output_1])

# %%
# Descomentar para ver
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Store_input (InputLayer)       [(None, 1)]          0           []
#
#  DayOfWeek_input (InputLayer)   [(None, 1)]          0           []
#
#  Store_Embed (Embedding)        (None, 1, 50)        55750       ['Store_input[0][0]']
#
#  DayOfWeek_Embed (Embedding)    (None, 1, 2)         14          ['DayOfWeek_input[0][0]']
#
#  Store_flat (Flatten)           (None, 50)           0           ['Store_Embed[0][0]']
#
#  DayOfWeek_flat (Flatten)       (None, 2)            0           ['DayOfWeek_Embed[0][0]']
#
#  BeforeStateHoliday_bool_input   [(None, 1)]         0           []
#  (InputLayer)
#
#  Max_TemperatureC_input (InputL  [(None, 1)]         0           []
#  ayer)
#
#  All_Concatenate (Concatenate)  (None, 54)           0           ['Store_flat[0][0]',
#                                                                   'DayOfWeek_flat[0][0]',
#                                                                   'BeforeStateHoliday_bool_input[0
#                                                                  ][0]',
#                                                                   'Max_TemperatureC_input[0][0]']
#
#  dense_2 (Dense)                (None, 1000)         55000       ['All_Concatenate[0][0]']
#
#  activation_2 (Activation)      (None, 1000)         0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 500)          500500      ['activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 500)          0           ['dense_3[0][0]']
#
#  Sales (Dense)                  (None, 1)            501         ['activation_3[0][0]']
#
#  Customers (Dense)              (None, 1)            501         ['activation_3[0][0]']
#
# ==================================================================================================
# Total params: 612,266
# Trainable params: 612,266
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.save_weights('initial_weights.hdf5')

# %%
df_train = df[df.Date < datetime.datetime(2015, 7, 1)]  
df_val = df[df.Date >= datetime.datetime(2015, 7, 1)]
print(f'Cantidad en val: {len(df_val)}, porcentaje: {len(df_train)/(len(df_train) + len(df_val))}')
# Out:
# Cantidad en val: 30188, porcentaje: 0.9642465458145908

# %%
from matplotlib import pyplot as plt
# plt.figure(figsize=(20,5))
# plt.plot((df_train[df_train['Store']==1]['Sales'].values - df_train[df_train['Store']==1]['Sales'].mean())/df_train[df_train['Store']==1]['Sales'].std())
# plt.show()
# plt.figure(figsize=(20,5))
# plt.plot(np.log(df_train[df_train['Store']==1]['Sales'].values)/np.max(np.log(df_train[df_train['Store']==1]['Sales'].values)))
# plt.show()

# %%
stores_mean = {}
for store, g_df in df_train.groupby('Store'):
    stores_mean[store] = g_df[g_df['Sales'] > 0]['Sales'].mean()

# %%
df_train.loc[:, 'mean_by_store'] = df_train['Store'].apply(stores_mean.get)
df_val.loc[:, 'mean_by_store'] = df_val['Store'].apply(stores_mean.get)

df_train.loc[:, 'Sales_store'] = df_train['Sales'] - df_train['mean_by_store']
df_val.loc[:, 'Sales_store'] = df_val['Sales'] - df_val['mean_by_store']
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %%
from tensorflow.keras import backend as K

# %%
def rmspe(y_true, y_pred):
    return K.sqrt(K.mean(K.square((y_true - y_pred)/y_true)))

# %%
def get_metric(df, sales_):
    return np.sqrt((((df['Sales'] - sales_)/df['Sales'])**2).mean())

# %%
get_metric(df_val, df_val['mean_by_store'])
# Out:
# 0.3071746085338871

# %%
all_vars = cat_vars + contin_vars
X_train = np.hsplit(df_train[all_vars].values, len(all_vars))
X_val = np.hsplit(df_val[all_vars].values, len(all_vars))
X_test = np.hsplit(df_test[all_vars].values, len(all_vars))

# %%
if add_customers:
    y_out_columns = ['Sales', 'Customers']
else:
    y_out_columns = ['Sales_store']
    
if log_output:
    # Escala logaritmica
    max_log_y = np.max(np.log(df[y_out_columns])).values
    y_train = np.log(df_train[y_out_columns].values)/max_log_y
    y_val = np.log(df_val[y_out_columns].values)/max_log_y
else:
    # Normalización
    y_mean = df_train[y_out_columns].mean().values
    y_std = df_train[y_out_columns].std().values
    y_train = (df_train[y_out_columns].values - y_mean)/y_std
    y_val = (df_val[y_out_columns].values - y_mean)/y_std
    y_max = df_train[y_out_columns].max().values
    y_train = df_train[y_out_columns].values/y_max
    y_val = df_val[y_out_columns].values/y_max
y_train = np.hsplit(y_train, y_train.shape[1])
y_val = np.hsplit(y_val, y_val.shape[1])

# %%
lr = 0.001
model.compile(optimizer=Adam(lr=lr), metrics=['mse', rmspe], loss='mse')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
if add_customers:
    checkpoint = ModelCheckpoint('bestmodel.hdf5', monitor='val_Sales_mse', verbose=1, save_best_only=True)
else:
    checkpoint = ModelCheckpoint('bestmodel.hdf5', monitor='val_loss', verbose=1, save_best_only=True)

# %%
epochs = 20
batch_size = 256
history = model.fit(X_train, y_train, validation_data=(X_val, y_val),  epochs=epochs, batch_size=batch_size, callbacks=[checkpoint], verbose=2)
# Out:
# Epoch 1/20
#
# Epoch 1: val_Sales_mse improved from inf to 0.00165, saving model to bestmodel.hdf5
# 3181/3181 - 107s - loss: 0.0066 - Sales_loss: 0.0023 - Customers_loss: 8.3572e-04 - Sales_mse: 0.0023 - Sales_rmspe: 0.3545 - Customers_mse: 8.3572e-04 - Customers_rmspe: 0.3186 - val_loss: 0.0025 - val_Sales_loss: 0.0017 - val_Customers_loss: 6.4933e-04 - val_Sales_mse: 0.0017 - val_Sales_rmspe: 0.2537 - val_Customers_mse: 6.4933e-04 - val_Customers_rmspe: 0.2405 - 107s/epoch - 34ms/step
# Epoch 2/20
#
# Epoch 2: val_Sales_mse improved from 0.00165 to 0.00150, saving model to bestmodel.hdf5
# 3181/3181 - 88s - loss: 0.0027 - Sales_loss: 0.0020 - Customers_loss: 5.2284e-04 - Sales_mse: 0.0020 - Sales_rmspe: 0.3274 - Customers_mse: 5.2284e-04 - Customers_rmspe: 0.2761 - val_loss: 0.0020 - val_Sales_loss: 0.0015 - val_Customers_loss: 3.7446e-04 - val_Sales_mse: 0.0015 - val_Sales_rmspe: 0.2401 - val_Customers_mse: 3.7446e-04 - val_Customers_rmspe: 0.2140 - 88s/epoch - 28ms/step
# Epoch 3/20
#
# Epoch 3: val_Sales_mse did not improve from 0.00150
# 3181/3181 - 91s - loss: 0.0025 - Sales_loss: 0.0019 - Customers_loss: 4.5660e-04 - Sales_mse: 0.0019 - Sales_rmspe: 0.3198 - Customers_mse: 4.5660e-04 - Customers_rmspe: 0.2623 - val_loss: 0.0020 - val_Sales_loss: 0.0015 - val_Customers_loss: 3.5660e-04 - val_Sales_mse: 0.0015 - val_Sales_rmspe: 0.2314 - val_Customers_mse: 3.5660e-04 - val_Customers_rmspe: 0.1933 - 91s/epoch - 29ms/step
# Epoch 4/20
#
# Epoch 4: val_Sales_mse improved from 0.00150 to 0.00142, saving model to bestmodel.hdf5
# 3181/3181 - 85s - loss: 0.0025 - Sales_loss: 0.0019 - Customers_loss: 4.5184e-04 - Sales_mse: 0.0019 - Sales_rmspe: 0.3129 - Customers_mse: 4.5184e-04 - Customers_rmspe: 0.2551 - val_loss: 0.0019 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.4620e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2284 - val_Customers_mse: 3.4620e-04 - val_Customers_rmspe: 0.1904 - 85s/epoch - 27ms/step
# Epoch 5/20
#
# Epoch 5: val_Sales_mse improved from 0.00142 to 0.00141, saving model to bestmodel.hdf5
# 3181/3181 - 85s - loss: 0.0024 - Sales_loss: 0.0019 - Customers_loss: 4.4841e-04 - Sales_mse: 0.0019 - Sales_rmspe: 0.3084 - Customers_mse: 4.4841e-04 - Customers_rmspe: 0.2525 - val_loss: 0.0019 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.4559e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2498 - val_Customers_mse: 3.4559e-04 - val_Customers_rmspe: 0.2030 - 85s/epoch - 27ms/step
# Epoch 6/20
#
# Epoch 6: val_Sales_mse did not improve from 0.00141
# 3181/3181 - 87s - loss: 0.0024 - Sales_loss: 0.0019 - Customers_loss: 4.4627e-04 - Sales_mse: 0.0019 - Sales_rmspe: 0.3063 - Customers_mse: 4.4627e-04 - Customers_rmspe: 0.2510 - val_loss: 0.0019 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.5933e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2567 - val_Customers_mse: 3.5933e-04 - val_Customers_rmspe: 0.2078 - 87s/epoch - 27ms/step
# Epoch 7/20
#
# Epoch 7: val_Sales_mse improved from 0.00141 to 0.00138, saving model to bestmodel.hdf5
# 3181/3181 - 87s - loss: 0.0024 - Sales_loss: 0.0019 - Customers_loss: 4.4546e-04 - Sales_mse: 0.0019 - Sales_rmspe: 0.3057 - Customers_mse: 4.4546e-04 - Customers_rmspe: 0.2506 - val_loss: 0.0018 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.4312e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2255 - val_Customers_mse: 3.4312e-04 - val_Customers_rmspe: 0.1889 - 87s/epoch - 27ms/step
# Epoch 8/20
#
# Epoch 8: val_Sales_mse improved from 0.00138 to 0.00136, saving model to bestmodel.hdf5
# 3181/3181 - 87s - loss: 0.0024 - Sales_loss: 0.0019 - Customers_loss: 4.4397e-04 - Sales_mse: 0.0019 - Sales_rmspe: 0.3051 - Customers_mse: 4.4397e-04 - Customers_rmspe: 0.2497 - val_loss: 0.0018 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.4576e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2385 - val_Customers_mse: 3.4576e-04 - val_Customers_rmspe: 0.1994 - 87s/epoch - 27ms/step
# Epoch 9/20
#
# Epoch 9: val_Sales_mse did not improve from 0.00136
# 3181/3181 - 87s - loss: 0.0024 - Sales_loss: 0.0019 - Customers_loss: 4.4209e-04 - Sales_mse: 0.0019 - Sales_rmspe: 0.3046 - Customers_mse: 4.4209e-04 - Customers_rmspe: 0.2488 - val_loss: 0.0019 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.7821e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2486 - val_Customers_mse: 3.7821e-04 - val_Customers_rmspe: 0.2241 - 87s/epoch - 27ms/step
# Epoch 10/20
#
# Epoch 10: val_Sales_mse improved from 0.00136 to 0.00135, saving model to bestmodel.hdf5
# 3181/3181 - 86s - loss: 0.0024 - Sales_loss: 0.0018 - Customers_loss: 4.4152e-04 - Sales_mse: 0.0018 - Sales_rmspe: 0.3041 - Customers_mse: 4.4152e-04 - Customers_rmspe: 0.2478 - val_loss: 0.0018 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.4974e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2395 - val_Customers_mse: 3.4974e-04 - val_Customers_rmspe: 0.2027 - 86s/epoch - 27ms/step
# Epoch 11/20
#
# Epoch 11: val_Sales_mse did not improve from 0.00135
# 3181/3181 - 84s - loss: 0.0024 - Sales_loss: 0.0018 - Customers_loss: 4.3884e-04 - Sales_mse: 0.0018 - Sales_rmspe: 0.3034 - Customers_mse: 4.3884e-04 - Customers_rmspe: 0.2462 - val_loss: 0.0020 - val_Sales_loss: 0.0016 - val_Customers_loss: 3.4592e-04 - val_Sales_mse: 0.0016 - val_Sales_rmspe: 0.2263 - val_Customers_mse: 3.4592e-04 - val_Customers_rmspe: 0.1903 - 84s/epoch - 27ms/step
# Epoch 12/20
#
# Epoch 12: val_Sales_mse improved from 0.00135 to 0.00135, saving model to bestmodel.hdf5
# 3181/3181 - 82s - loss: 0.0024 - Sales_loss: 0.0018 - Customers_loss: 4.3575e-04 - Sales_mse: 0.0018 - Sales_rmspe: 0.3016 - Customers_mse: 4.3575e-04 - Customers_rmspe: 0.2443 - val_loss: 0.0018 - val_Sales_loss: 0.0013 - val_Customers_loss: 3.7166e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2310 - val_Customers_mse: 3.7166e-04 - val_Customers_rmspe: 0.2059 - 82s/epoch - 26ms/step
# Epoch 13/20
#
# Epoch 13: val_Sales_mse did not improve from 0.00135
# 3181/3181 - 81s - loss: 0.0024 - Sales_loss: 0.0018 - Customers_loss: 4.3452e-04 - Sales_mse: 0.0018 - Sales_rmspe: 0.3013 - Customers_mse: 4.3452e-04 - Customers_rmspe: 0.2439 - val_loss: 0.0018 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.2902e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2235 - val_Customers_mse: 3.2902e-04 - val_Customers_rmspe: 0.2014 - 81s/epoch - 25ms/step
# Epoch 14/20
#
# Epoch 14: val_Sales_mse did not improve from 0.00135
# 3181/3181 - 80s - loss: 0.0024 - Sales_loss: 0.0018 - Customers_loss: 4.3116e-04 - Sales_mse: 0.0018 - Sales_rmspe: 0.3006 - Customers_mse: 4.3116e-04 - Customers_rmspe: 0.2426 - val_loss: 0.0018 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.2154e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2183 - val_Customers_mse: 3.2154e-04 - val_Customers_rmspe: 0.1837 - 80s/epoch - 25ms/step
# Epoch 15/20
#
# Epoch 15: val_Sales_mse improved from 0.00135 to 0.00132, saving model to bestmodel.hdf5
# 3181/3181 - 82s - loss: 0.0023 - Sales_loss: 0.0018 - Customers_loss: 4.1446e-04 - Sales_mse: 0.0018 - Sales_rmspe: 0.2949 - Customers_mse: 4.1446e-04 - Customers_rmspe: 0.2350 - val_loss: 0.0018 - val_Sales_loss: 0.0013 - val_Customers_loss: 3.3708e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2280 - val_Customers_mse: 3.3708e-04 - val_Customers_rmspe: 0.2054 - 82s/epoch - 26ms/step
# Epoch 16/20
#
# Epoch 16: val_Sales_mse did not improve from 0.00132
# 3181/3181 - 80s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.8912e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2856 - Customers_mse: 3.8912e-04 - Customers_rmspe: 0.2220 - val_loss: 0.0018 - val_Sales_loss: 0.0013 - val_Customers_loss: 3.5388e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2232 - val_Customers_mse: 3.5388e-04 - val_Customers_rmspe: 0.2129 - 80s/epoch - 25ms/step
# Epoch 17/20
#
# Epoch 17: val_Sales_mse did not improve from 0.00132
# 3181/3181 - 83s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.8035e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2813 - Customers_mse: 3.8035e-04 - Customers_rmspe: 0.2144 - val_loss: 0.0018 - val_Sales_loss: 0.0013 - val_Customers_loss: 3.3091e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2154 - val_Customers_mse: 3.3091e-04 - val_Customers_rmspe: 0.1876 - 83s/epoch - 26ms/step
# Epoch 18/20
#
# Epoch 18: val_Sales_mse improved from 0.00132 to 0.00130, saving model to bestmodel.hdf5
# 3181/3181 - 80s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.7411e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2801 - Customers_mse: 3.7411e-04 - Customers_rmspe: 0.2102 - val_loss: 0.0017 - val_Sales_loss: 0.0013 - val_Customers_loss: 3.1481e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2129 - val_Customers_mse: 3.1481e-04 - val_Customers_rmspe: 0.1749 - 80s/epoch - 25ms/step
# Epoch 19/20
#
# Epoch 19: val_Sales_mse did not improve from 0.00130
# 3181/3181 - 80s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.7004e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2796 - Customers_mse: 3.7004e-04 - Customers_rmspe: 0.2081 - val_loss: 0.0018 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.6688e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2318 - val_Customers_mse: 3.6688e-04 - val_Customers_rmspe: 0.1904 - 80s/epoch - 25ms/step
# Epoch 20/20
#
# Epoch 20: val_Sales_mse did not improve from 0.00130
# 3181/3181 - 81s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.6968e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2801 - Customers_mse: 3.6968e-04 - Customers_rmspe: 0.2076 - val_loss: 0.0018 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.6545e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2278 - val_Customers_mse: 3.6545e-04 - val_Customers_rmspe: 0.1929 - 81s/epoch - 25ms/step

# %%
plt.plot(history.history['val_loss'])
# plt.plot(history.history['val_Customers_mse'])
# plt.plot(history.history['val_Sales_mse'])
plt.show()
plt.plot(history.history['loss'])
# plt.plot(history.history['Customers_mse'])
# plt.plot(history.history['Sales_mse'])

# %% [markdown]
# # Métrica

# %% [markdown]
# $$
# \textrm{RMSE} = \sqrt{\frac{1}{n} \sum_{i=1}^{n} \left(\frac{\hat{y}_i - y_i}{y_i}\right)^2}
# $$

# %%
model.evaluate(X_val, y_val)
# Out:
# 944/944 [==============================] - 4s 4ms/step - loss: 0.0017 - Sales_loss: 0.0013 - Customers_loss: 3.1481e-04 - Sales_mse: 0.0013 - Sales_rmspe: 0.2096 - Customers_mse: 3.1481e-04 - Customers_rmspe: 0.1715
# [0.0017078551463782787,
#  0.0012976146535947919,
#  0.0003148138348478824,
#  0.0012976146535947919,
#  0.2095596045255661,
#  0.0003148138348478824,
#  0.17145882546901703]

# %%
model.load_weights('bestmodel.hdf5')
model.evaluate(X_val, y_val)
# Out:
# 944/944 [==============================] - 5s 5ms/step - loss: 0.0017 - Sales_loss: 0.0013 - Customers_loss: 3.1481e-04 - Sales_mse: 0.0013 - Sales_rmspe: 0.2096 - Customers_mse: 3.1481e-04 - Customers_rmspe: 0.1715
# [0.0017078551463782787,
#  0.0012976146535947919,
#  0.0003148138348478824,
#  0.0012976146535947919,
#  0.2095596045255661,
#  0.0003148138348478824,
#  0.17145882546901703]

# %%
# model.load_weights('bestmodel.hdf5')
# model.evaluate(X_val, y_val)
# 30188/30188 [==============================] - 5s 172us/step
# [0.12197033089921382,
#  0.07211007360268763,
#  0.037183713050426136,
#  0.07211007360268763,
#  0.037183713050426136]

# [0.12932546436786652,
#  0.07751645147800446,
#  0.039259567856788635,
#  0.07751645147800446,
#  0.039259567856788635]

# %%
if log_output:
    if add_customers:
        y_pred = np.exp(model.predict(X_val, verbose=1)[0][:, 0]*max_log_y[0])
        y_pred_test = np.exp(model.predict(X_test, verbose=1)[0][:, 0]*max_log_y[0])
    else:
        y_pred = np.exp(model.predict(X_val, verbose=1)*max_log_y)[:,0]
        y_pred_test = np.exp(model.predict(X_test, verbose=1)*max_log_y)[:,0]
else:
    if add_customers:
        y_pred = (model.predict(X_val, verbose=1)[0]*y_std[0] + y_mean[0])[:,0]
        y_pred_test = (model.predict(X_test, verbose=1)[0]*y_std[0] + y_mean[0])[:,0]
    else:
#         y_pred = model.predict(X_val, verbose=1)[:,0]*y_std + y_mean
#         y_pred_test = model.predict(X_test, verbose=1)[:,0]*y_std + y_mean
        y_pred = model.predict(X_val, verbose=1)[:,0]*y_max
        y_pred_test = model.predict(X_test, verbose=1)[:,0]*y_max
y_pred_test[df_test['Open'] == 0] = 0
# Out:
# 944/944 [==============================] - 4s 4ms/step
# 1284/1284 [==============================] - 5s 4ms/step

# %%
np.sqrt((((df_val['Sales'].values - y_pred)/df_val['Sales'].values)**2).sum()/len(y_pred))
# Out:
# 0.5842045659433222

# %%
y_pred_test[:10]
# Out:
# array([7340.7383, 7488.205 , 7613.1226, 7395.2954, 7441.3354, 7381.804 ,
#        7588.4062, 7538.091 , 7321.8057, 7402.4805], dtype=float32)

# %% [markdown]
# # Baseline

# %%
import pandas as pd
sample_csv = pd.read_csv('/content/drive/MyDrive/Redes Neuronales/TP2/rossman/sample_submission.csv')

# %%
stores_mean = {}
for store, g_df in df.groupby('Store'):
    stores_mean[store] = g_df[g_df['Sales'] > 0]['Sales'].mean()

# %%
df_test['Sales'] = df_test['Store'].apply(stores_mean.get)
df_test.loc[df_test['Open'] == 0, 'Sales'] = 0

# %%
df_test[['Store', 'Sales']].head(10)
# Out:
#    Store        Sales
# 0      0  4759.096031
# 1      2  6942.568678
# 2      6  8817.050891
# 3      7  5539.358418
# 4      8  6562.337612
# 5      9  5568.420918
# 6     10  8030.977041
# 7     11  7589.598214
# 8     12  5034.747182
# 9     13  5508.567394

# %%
df_test[df_test['Open'] == 0][['Store', 'Sales']].head()
# Out:
#       Store  Sales
# 543     702    0.0
# 676     878    0.0
# 840    1096    0.0
# 1399    702    0.0
# 1532    878    0.0

# %%
sample_csv['Sales'] = df_test['Sales']

# %%
sample_csv.to_csv(f'submision_baseline.csv', index=False)

# %%
sample_csv.head()
# Out:
#    Id        Sales
# 0   1  4759.096031
# 1   2  6942.568678
# 2   3  8817.050891
# 3   4  5539.358418
# 4   5  6562.337612

# %% [markdown]
# # Sumbit a la competición

# %%
sample_csv = pd.read_csv('/content/drive/MyDrive/Redes Neuronales/TP2/rossman/sample_submission.csv')
sample_csv['Sales'] = y_pred_test
sample_csv.head()

sample_csv.to_csv(f'submision_{add_customers}-{log_output}-{output_activation}-{l2_lambda}-{first_hidden_units}-{epochs}-{batch_size}-{lr}.csv', index=False)

# %%
from google.colab import files

files.download(f'submision_baseline.csv')
files.download(f'submision_{add_customers}-{log_output}-{output_activation}-{l2_lambda}-{first_hidden_units}-{epochs}-{batch_size}-{lr}.csv')

# %% [markdown]
# # Analisis de embedings

# %%
def plot_embed(layer_name, cat_names):
    Y = model.get_layer(layer_name).get_weights()[0]
    print(Y.shape)
    plt.figure(figsize=(8,8))
    plt.scatter(-Y[:, 0], -Y[:, 1])
    for i, txt in enumerate(cat_names):
        plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-5, 8), textcoords = 'offset points')

# %%
model.load_weights('bestmodel.hdf5')
plot_embed('DayOfWeek_Embed', ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat','Sun'])
# Out:
# (7, 2)

# %%
#plot_embed('Month_Embed', list(range(12)))

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

# %%
#day_of_week_embedding.shape

# %%
#tsne = TSNE(n_components=2, random_state=1, learning_rate=10, n_iter=10000)
#Y = tsne.fit_transform(day_of_week_embedding)
#names = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat','Sun']
#plt.figure(figsize=(8,8))
#plt.scatter(-Y[:, 0], -Y[:, 1])
#for i, txt in enumerate(names):
#    plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-5, 8), textcoords = 'offset points')

# %%
cat_vars
# Out:
# ['Store', 'DayOfWeek']

# %% [markdown]
# ## Store embeddings

# %%
submodel = Model(cat_var_inputs + cont_vars_inputs, merged)

# %%
submodel.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Store_input (InputLayer)       [(None, 1)]          0           []
#
#  DayOfWeek_input (InputLayer)   [(None, 1)]          0           []
#
#  Store_Embed (Embedding)        (None, 1, 50)        55750       ['Store_input[0][0]']
#
#  DayOfWeek_Embed (Embedding)    (None, 1, 2)         14          ['DayOfWeek_input[0][0]']
#
#  Store_flat (Flatten)           (None, 50)           0           ['Store_Embed[0][0]']
#
#  DayOfWeek_flat (Flatten)       (None, 2)            0           ['DayOfWeek_Embed[0][0]']
#
#  BeforeStateHoliday_bool_input   [(None, 1)]         0           []
#  (InputLayer)
#
#  Max_TemperatureC_input (InputL  [(None, 1)]         0           []
#  ayer)
#
#  All_Concatenate (Concatenate)  (None, 54)           0           ['Store_flat[0][0]',
#                                                                   'DayOfWeek_flat[0][0]',
#                                                                   'BeforeStateHoliday_bool_input[0
#                                                                  ][0]',
#                                                                   'Max_TemperatureC_input[0][0]']
#
# ==================================================================================================
# Total params: 55,764
# Trainable params: 55,764
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
submodel.save('embeddings_model.hdf5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
files.download('initial_weights.hdf5')
files.download('bestmodel.hdf5')
files.download('embeddings_model.hdf5')
